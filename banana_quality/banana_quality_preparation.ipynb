# %%
import pandas as pd
import datetime as dt

# dataset originally taken from https://www.kaggle.com/datasets/l3llff/banana/data
df = pd.read_csv('banana_quality_raw.csv')

df = df.sample(frac=1)
df = df.reset_index(drop=True)
# add artificial timestamp
timestamps = [dt.datetime(2020,1,1) + dt.timedelta(hours=x/2) for x in df.index]
df['Timestamp'] = timestamps
df['Quality'] = df['Quality'].map({'Bad': 0, 'Good':1})
df = df[['Timestamp', 'Size', 'Weight', 'Sweetness', 'Softness', 'HarvestTime', 'Ripeness', 'Acidity', 'Quality']]
df.to_csv('banana_quality.csv', index=False)

# %%
df.head()
# Out:
#             Timestamp      Size    Weight  Sweetness  Softness  HarvestTime  \
# 0 2020-01-01 00:00:00  2.622631 -1.531197  -0.293286  2.086239     4.379607
# 1 2020-01-01 00:30:00 -3.592020  0.220773   0.298705 -1.759699    -4.116195
# 2 2020-01-01 01:00:00  1.270482 -3.959625  -3.447087  0.799014     0.148791
# 3 2020-01-01 01:30:00 -0.002022 -1.417225  -1.847301  0.301628     1.364337
# 4 2020-01-01 02:00:00 -0.786569 -4.323583   1.466369  0.157923    -2.063598
#
#    Ripeness   Acidity  Quality
# 0  0.865033  0.139479        1
# 1  0.604932 -2.387580        1
# 2 -2.098769  0.727079        0
# 3  0.265501 -0.458392        1
# 4  2.619294 -0.340423        0
